# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()
api_key  = os.getenv('OPENAI_APIKEY')

# %%
def check_openai_api_key(api_key):
    client = OpenAI(api_key=api_key)
    try:
        # モデルのリストを取得して、API キーの有効性を確認
        client.models.list()
    except Exception as e:
        print(f"エラーが発生しました: {e}")
        return False  # API キーが無効またはエラー
    else:
        return True  # API キーが有効

# 実際の API キーをここに入力
is_valid = check_openai_api_key(api_key)
print(is_valid)
# Out:
# True

# %% [markdown]
# ### まずは，次にくる単語を予測

# %%
question='To be or not to '
model="gpt-3.5-turbo"

client = OpenAI(
    # This is the default and can be omitted
    api_key=api_key,
)

response = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": question,
        }
    ],
    model=model,
    max_tokens=2,
    temperature=0.7
)

# %%
print(response)
print(response.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-BQ81z9K3lvPjgzc7GnhXKQG8Shrwj', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='be,', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1745567099, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=2, prompt_tokens=13, total_tokens=15, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# be,

# %% [markdown]
# ### 次に，コンテキストを入れる
# - あなたは東京理科大学の卒業生だと教える(ここでは敢えて英語で与えてます)
# - system, user, assistantというroleを想定
# - あなたはどこの大学卒業？と聞く

# %%
question='あなたはどこの学校を卒業してますか？'
model="gpt-3.5-turbo"
messages=[
        {"role": "system",
        "content": "\
        you have graduated from  Tokyo Univerisity of Science\
          "},
        {"role": "user", "content": question}
]

response = client.chat.completions.create(
    messages=messages,
    model=model,
    max_tokens=100,
    temperature=0.7
)

# %%
print(response)
print(response.choices[0].message.role,response.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-BQ820BtHFmi6xOCe6Rwl7LfSxkFbN', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='私は東京理科大学を卒業しました。', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1745567100, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=18, prompt_tokens=43, total_tokens=61, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# assistant 私は東京理科大学を卒業しました。

# %%
path = "FKG004_20241102_094934.txt"

try:
    with open(path, 'r') as file:
        # ファイルの内容を読み込む
        file_content = file.read()

        # 読み込んだ内容を表示する
        print(file_content)

except FileNotFoundError:
    print(f"ファイルが見つかりません: {path}")
except Exception as e:
    print(f"エラーが発生しました: {e}")
# Out:
# 第214回国会　参議院　本会議　第1号　令和6年10月1日
#
# 令和六年十月一日（火曜日）
# 　　　午前十時二分開議
# 　　　　━━━━━━━━━━━━━
# ○議事日程　第一号
# 　　令和六年十月一日
# 　　　午前十時開議
# 　第一　議席の指定
# 　第二　会期の件
# 　　　　━━━━━━━━━━━━━
# ○本日の会議に付した案件
# 　一、日程第一
# 　一、元議員渡辺秀央君逝去につき哀悼の件
# 　一、常任委員長辞任の件
# 　一、常任委員長の選挙
# 　一、特別委員会設置の件
# 　一、情報監視審査会委員辞任の件
# 　一、情報監視審査会委員の選任
# 　一、日程第二
# 　一、内閣総理大臣の指名
# 　　　　　─────・─────
# ○議長（尾辻秀久君）　第二百十四回国会は本日召集されました。
# 　これより会議を開きます。
# 　日程第一　議席の指定
# 　議長は、本院規則第十四条の規定により、諸君の議席をただいまの仮議席のとおりに指定いたします。
# 　　　　　─────・─────
# ○議長（尾辻秀久君）　さきに院議をもって永年在職議員として表彰されました元議員渡辺秀央君は、去る七月三十一日逝去されました。誠に痛惜の極みであり、哀悼の念に堪えません。
# 　同君に対しましては、議長は、既に弔詞をささげました。
# 　ここにその弔詞を朗読いたします。
# 　　　〔総員起立〕
# 　参議院は　わが国　民主政治発展のため力を尽くされ　特に院議をもって永年の功労を表彰せられ　さきに経済産業委員長の要職に就かれ　また国務大臣としての重任にあたられました　元議員従三位旭日大綬章渡辺秀央君の長逝に対し　つつしんで哀悼の意を表し　うやうやしく弔詞をささげます
# 　　　　　─────・─────
# ○議長（尾辻秀久君）　この際、常任委員長の辞任についてお諮りいたします。
# 　総務委員長新妻秀規君、法務委員長佐々木さやか君、議院運営委員長浅尾慶一郎君から、それぞれ常任委員長を辞任いたしたいとの申出がございました。
# 　いずれも許可することに御異議ございませんか。
# 　　　〔「異議なし」と呼ぶ者あり〕
# ○議長（尾辻秀久君）　御異議ないと認めます。
# 　よって、いずれも許可することに決しました。
# ...

# %%
question = "次の国会答弁を要約して ---\n"
model = "gpt-4.1"

client = OpenAI(
    api_key = api_key,
)

question = question + file_content
print(question)
# Out:
# 次の国会答弁を要約して ---
# ﻿第214回国会　参議院　本会議　第1号　令和6年10月1日
#
# 令和六年十月一日（火曜日）
# 　　　午前十時二分開議
# 　　　　━━━━━━━━━━━━━
# ○議事日程　第一号
# 　　令和六年十月一日
# 　　　午前十時開議
# 　第一　議席の指定
# 　第二　会期の件
# 　　　　━━━━━━━━━━━━━
# ○本日の会議に付した案件
# 　一、日程第一
# 　一、元議員渡辺秀央君逝去につき哀悼の件
# 　一、常任委員長辞任の件
# 　一、常任委員長の選挙
# 　一、特別委員会設置の件
# 　一、情報監視審査会委員辞任の件
# 　一、情報監視審査会委員の選任
# 　一、日程第二
# 　一、内閣総理大臣の指名
# 　　　　　─────・─────
# ○議長（尾辻秀久君）　第二百十四回国会は本日召集されました。
# 　これより会議を開きます。
# 　日程第一　議席の指定
# 　議長は、本院規則第十四条の規定により、諸君の議席をただいまの仮議席のとおりに指定いたします。
# 　　　　　─────・─────
# ○議長（尾辻秀久君）　さきに院議をもって永年在職議員として表彰されました元議員渡辺秀央君は、去る七月三十一日逝去されました。誠に痛惜の極みであり、哀悼の念に堪えません。
# 　同君に対しましては、議長は、既に弔詞をささげました。
# 　ここにその弔詞を朗読いたします。
# 　　　〔総員起立〕
# 　参議院は　わが国　民主政治発展のため力を尽くされ　特に院議をもって永年の功労を表彰せられ　さきに経済産業委員長の要職に就かれ　また国務大臣としての重任にあたられました　元議員従三位旭日大綬章渡辺秀央君の長逝に対し　つつしんで哀悼の意を表し　うやうやしく弔詞をささげます
# 　　　　　─────・─────
# ○議長（尾辻秀久君）　この際、常任委員長の辞任についてお諮りいたします。
# 　総務委員長新妻秀規君、法務委員長佐々木さやか君、議院運営委員長浅尾慶一郎君から、それぞれ常任委員長を辞任いたしたいとの申出がございました。
# 　いずれも許可することに御異議ございませんか。
# 　　　〔「異議なし」と呼ぶ者あり〕
# ○議長（尾辻秀久君）　御異議ないと認めます。
# ...

# %%
response = client.chat.completions.create(
    messages = [
        {
            "role" : "user",
            "content" : question,
        }
    ],
    model=model,
    max_tokens=600,
    temperature=0.7
)

# %%
print(response)
print(response.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-BQ826m9yMLWchmKmRnEYkybR3RPU9', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='【要約】\n\n令和6年10月1日に召集された第214回国会（参議院本会議 第1号）の主な内容は以下の通りです。\n\n---\n\n### 1. 開会・議席指定\n- 本会議が開かれ、議席指定など国会冒頭の手続きが行われた。\n\n### 2. 渡辺秀央元議員への哀悼\n- 永年在職議員表彰も受けた元議員・渡辺秀央氏の逝去に対し、議長から哀悼の意が表明された。\n\n### 3. 委員長人事\n- 総務委員長、法務委員長、議院運営委員長の辞任が許可され、新たに宮崎勝氏（総務）、若松謙維氏（法務）、牧野たかお氏（議運）が指名された。\n\n### 4. 特別委員会の設置\n- 災害対策、政府開発援助・沖縄北方問題、政治改革、拉致問題、地方創生・デジタル社会、消費者問題、東日本大震災復興に関する7つの特別委員会が設置され、その委員が指名された。\n\n### 5. 情報監視審査会委員の交代\n- 浜口誠氏の辞任が許可され、後任に田名部匡代氏が選任された。\n\n### 6. 会期の決定と討論\n- 今期国会の会期を9日間（10月1日〜10月9日）とする案に対し、立憲民主・社民・無所属の吉川沙織氏が反対討論。\n  - 新自民党総裁による衆院解散表明の手続き・タイミングへの疑問\n  - 衆院選準備や国会審議、政治倫理問題などへの真摯な対応を求める\n  - 会期が短すぎることで十分な審議ができないことを批判\n- 記名投票の結果、賛成146票、反対96票で「会期9日間」が決定。\n\n### 7. 内閣総辞職と総理大臣指名\n- 岸田内閣が総辞職した旨が報告された。\n- 新たな内閣総理大臣の指名投票が行われ、石破茂氏が143票で指名された（次点：野田', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None
# ...

# %%
question = """
#命令文
以下のフォーマットでマークダウン形式で，国会の本会議の議事録を作成して

# 会議名

# 日時

# 出席者

#決定事項
- 決定事項1 {{contents}}
- 決定事項2 {{contents}}

# 残課題

# その他要約

---
以下が本文です．
"""

question = question + file_content

# %%
response = client.chat.completions.create(
    messages = [
        {
            "role" : "user",
            "content" : question,
        }
    ],
    model=model,
    max_tokens=1000,
    temperature=0.7
)

# %%
print(response)
print(response.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-BQ82EHytnojV2akLkMBeqPqMEF5LJ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```markdown\n# 第214回国会 参議院 本会議 第1号 議事録\n\n# 日時\n令和6年（2024年）10月1日（火曜日）  \n午前10時2分開議 ～ 午後3時13分散会\n\n# 出席者\n- 議長：尾辻秀久\n- 参議院議員各位\n- 記名投票者計242名（投票者詳細は割愛）\n\n# 決定事項\n- 決定事項1 議席の指定\n  - 議長は本院規則第十四条により、諸君の議席を仮議席のとおりに指定した。\n- 決定事項2 会期の決定\n  - 本会期を令和6年10月1日から10月9日までの9日間とすることが、記名投票（賛成146、反対96）により決定した。\n- 決定事項3 常任委員長の辞任と新任\n  - 総務、法務、議院運営各委員長の辞任を許可し、新たに宮崎勝（総務）、若松謙維（法務）、牧野たかお（議院運営）を指名。\n- 決定事項4 特別委員会の設置と委員指名\n  - 災害対策特別委員会、政府開発援助等及び沖縄・北方問題に関する特別委員会、政治改革特別委員会、北朝鮮拉致問題等特別委員会、地方創生及びデジタル社会形成特別委員会、消費者問題特別委員会、東日本大震災復興特別委員会の設置と、各委員の指名を決定。\n- 決定事項5 情報監視審査会委員の辞任・新任\n  - 浜口誠の辞任を許可、田名部匡代を新たに選任。\n- 決定事項6 内閣総理大臣の指名\n  - 記名投票の結果、石破茂を第101代内閣総理大臣に指名した（143票で過半数、他候補は詳細割愛）。\n\n# 残課題\n- 国会会期の短さ・審議の不十分さに対する野党の不満が表明された。\n- 旧優生保護法訴訟への対応、頻発する災害への迅速な対処。\n- 一部自民党議員の政治資金収支報告不記載等、政治倫理審査会における説明責任未履行。\n- 衆議院解散に伴う国会運営・選挙管理執行への懸念。\n\n# その他要約\n- 元議員渡辺秀央氏の逝去につき、議場で哀悼の意を表し
# ...

# %%
question = """
文章の中の人名を抜き出してリストのようにまとめてください。なお、重複はないようにしてください。

（文章）
○議長（尾辻秀久君）　第二百十四回国会は本日召集されました。

（出力）
尾辻秀久、
"""

question = question + file_content

# %%
response1 = client.chat.completions.create(
    messages = [
        {
            "role" : "user",
            "content" : question,
        }
    ],
    model=model,
    max_tokens=1000,
    temperature=0.7
)

# %%
print(response1)
print(response1.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-BQ8BBeINPQyAVudon8OkBXbAzDVb6', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='尾辻秀久  \n渡辺秀央  \n新妻秀規  \n佐々木さやか  \n浅尾慶一郎  \n宮崎勝  \n若松謙維  \n牧野たかお  \n阿達雅志  \n岩本剛人  \n加田裕之  \n加藤明良  \n梶原大介  \n古庄玄知  \n藤木眞也  \n堀井巌  \n宮崎雅夫  \n宮本周司  \n杉尾秀哉  \n羽田次郎  \n森本真治  \n上田勇  \n塩田博昭  \n嘉田由紀子  \n松野明美  \n舟山康江  \n仁比聡平  \n青木一彦  \n青山繁晴  \n朝日健太郎  \n井上義行  \n今井絵理子  \n臼井正一  \n江島潔  \n大家敏志  \n高橋克法  \n高橋はるみ  \n中西祐介  \n藤川政人  \n本田顕子  \n松山政司  \n三原じゅん子  \n三宅伸吾  \n若林洋平  \n勝部賢志  \n古賀之士  \n塩村あやか  \n田島麻衣子  \n徳永エリ  \n水野素子  \n秋野公造  \n河野義博  \n窪田哲也  \n安江伸夫  \n猪瀬直樹  \n音喜多駿  \n清水貴之  \n榛葉賀津也  \n浜口誠  \n紙智子  \n天畠大輔  \n高良鉄美  \n赤松健  \n石井浩郎  \n神谷政幸  \n佐藤正久  \n清水真人  \n白坂亜紀  \n鶴保庸介  \n友納理緒  \n豊田俊郎  \n永井学  \n藤井一博  \n青木愛  \n小沼巧  \n熊谷裕人  \n小西洋之  \n宮口治子  \n森屋隆  \n里見隆治  \n谷合正明  \n矢倉克夫  \n山本博司  \n梅村聡  \n高木かおり  \n藤巻健史  \n浜野喜史  \n井上哲士  \n山下芳生  \n舩後靖彦  \n齊藤健一郎  \n赤池誠章  \n衛藤晟一  \n北村経夫  \n小林一大  \n松下新平  \n山田宏  \n山谷えり子  \n吉井章  \n打越さく良  \n川田龍平  \n三上えり  \n石川博崇  \n中条きよし  \n柳
# ...

# %%
question = """
次の文章から自民党所属の人の名前を抽出してください.
(回答例)
1 尾辻秀久  
2 渡辺秀央  
3 新妻秀規  
4 佐々木さやか 
"""
question = question + response1.choices[0].message.content

# %%
response2 = client.chat.completions.create(
    messages = [
        {
            "role" : "user",
            "content" : question,
        }
    ],
    model=model,
    max_tokens=500,
    temperature=0.7
)

# %%
print(response2.choices[0].message.content)
# Out:
# 自民党所属の人名を抽出します。
#
# 1. 尾辻秀久
# 2. 阿達雅志
# 3. 岩本剛人
# 4. 加田裕之
# 5. 加藤明良
# 6. 梶原大介
# 7. 古庄玄知
# 8. 藤木眞也
# 9. 堀井巌
# 10. 宮崎雅夫
# 11. 宮本周司
# 12. 青木一彦
# 13. 青山繁晴
# 14. 朝日健太郎
# 15. 井上義行
# 16. 今井絵理子
# 17. 江島潔
# 18. 大家敏志
# 19. 高橋克法
# 20. 高橋はるみ
# 21. 中西祐介
# 22. 藤川政人
# 23. 松山政司
# 24. 三原じゅん子
# 25. 三宅伸吾
# 26. 若林洋平
# 27. 赤池誠章
# 28. 衛藤晟一
# 29. 北村経夫
# 30. 小林一大
# 31. 松下新平
# 32. 山田宏
# 33. 山谷えり子
# 34. 石井浩郎
# 35. 佐藤正久
# 36. 鶴保庸介
# 37. 豊田俊郎
# 38. 永井学
# 39. 藤井一博
# 40. 宮沢洋一
# 41. 森まさこ
# 42. 和田政宗
# 43. 太田房江
# 44. 進藤金日子
# 45. 長谷川英晴
# 46. 古川俊治
# 47. 山本啓介
# 48. 山本佐知子
# 49. 橋本聖子
# 50. 堂故茂
# 51. 羽生田俊
# 52. 星北斗
# 53. 三浦靖
# 54. 岸田文雄
# 55. 高市早苗
# 56. 茂木敏充
#
# （※漏れがある場合はご指摘ください）

# %%
question = """
では次の文章をcsv形式の文章にしなさい。なお出力結果はそのままcsvにするためcsv以外の情報を文字にしないこと。
（回答例）
尾辻秀久,  
阿達雅志, 
岩本剛人,
...
"""
question = question + response2.choices[0].message.content

# %%
response3 = client.chat.completions.create(
    messages = [
        {
            "role" : "user",
            "content" : question,
        }
    ],
    model=model,
    max_tokens=500,
    temperature=0.7
)

# %%
print(response3.choices[0].message.content)
# Out:
# 尾辻秀久,
# 阿達雅志,
# 岩本剛人,
# 加田裕之,
# 加藤明良,
# 梶原大介,
# 古庄玄知,
# 藤木眞也,
# 堀井巌,
# 宮崎雅夫,
# 宮本周司,
# 青木一彦,
# 青山繁晴,
# 朝日健太郎,
# 井上義行,
# 今井絵理子,
# 江島潔,
# 大家敏志,
# 高橋克法,
# 高橋はるみ,
# 中西祐介,
# 藤川政人,
# 松山政司,
# 三原じゅん子,
# 三宅伸吾,
# 若林洋平,
# 赤池誠章,
# 衛藤晟一,
# 北村経夫,
# 小林一大,
# 松下新平,
# 山田宏,
# 山谷えり子,
# 石井浩郎,
# 佐藤正久,
# 鶴保庸介,
# 豊田俊郎,
# 永井学,
# 藤井一博,
# 宮沢洋一,
# 森まさこ,
# 和田政宗,
# 太田房江,
# 進藤金日子,
# 長谷川英晴,
# 古川俊治,
# 山本啓介,
# 山本佐知子,
# 橋本聖子,
# 堂故茂,
# 羽生田俊,
# 星北斗,
# 三浦靖,
# 岸田文雄,
# 高市早苗,
# 茂木敏充,

# %%
import csv

lines = response3.choices[0].message.content.strip().splitlines()
cleaned_lines = [line.strip() for line in lines if line.strip()]
rows = [line.split(',') for line in cleaned_lines]  

with open('name.csv', 'w') as csvfile: # 'w'モードで開く
    writer = csv.writer(csvfile)
    writer.writerows(rows)
